# %% [markdown]
# ## Step 1: Install Required Libraries
#
# In this step, I install the required Python library 'pandas'.

# %%
# !python.exe -m pip install --upgrade pip

# %%
# !pip install pandas

# %% [markdown]
# ## Step 2: Import Libraries
#
# In this step, I import the pandas library to work with the dataset.

# %%
import pandas as pd

# %% [markdown]
# ## Step 3: Load Dataset
#
# In this step, I load the CSV dataset into a pandas DataFrame.

# %%
df = pd.read_csv("C:/Users/nikhi/PyCharmMiscProject/Week_1_Assignment/archive (1)/Combined_dataset.csv")

# %%
df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %% [markdown]
# ## Step 4: Data Exploration
#
# In this step, I explore the dataset using various functions.

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
df.shape
# Out:
# (1000, 24)

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   str
#  2   product_description     1000 non-null   str
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                879 non-null    float64
#  7   final_price             1000 non-null   str
#  8   currency                1000 non-null   str
#  9   images                  1000 non-null   str
#  10  delivery_options        1000 non-null   str
#  11  product_details         1000 non-null   str
#  12  breadcrumbs             1000 non-null   str
#  13  product_specifications  1000 non-null   str
#  14  amount_of_stars         1000 non-null   str
# ...

# %%
df.sample(5)
# Out:
#      product_id           title  \
# 173    13391540  Mast & Harbour
# 322    15188034           Metro
# 192    12944214  Cherry Crumble
# 516    19183770           Crocs
# 908    22568668          V-Mart
#
#                                    product_description  rating  ratings_count  \
# 173  EcoVero Women Yellow & White Abstract Printed ...     4.1            576
# 322                          Grey PU Swagger Sling Bag     4.3             10
# 192          Boys Olive Green Solid Corduroy Dungarees     3.8             11
# 516  Unisex Multicoloured Classic Spray Dye Croslit...     4.1             21
# 908      High Neck Puff Sleeves Gathered Georgette Top     3.7             30
#
#      initial_price  discount  final_price currency  \
# 173           1999      66.0    "₹679.00"      INR
# 322           1290       NaN  "₹1,290.00"      INR
# 192           2599      45.0  "₹1,429.00"      INR
# 516           3295      20.0  "₹2,636.00"      INR
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.dtypes
# Out:
# product_id                  int64
# title                         str
# product_description           str
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                   str
# currency                      str
# images                        str
# delivery_options              str
# product_details               str
# breadcrumbs                   str
# product_specifications        str
# amount_of_stars               str
# what_customers_said           str
# seller_name                   str
# sizes                         str
# videos                        str
# seller_information            str
# variations                    str
# best_offer                    str
# more_offers                   str
# category                      str
# dtype: object

# %%
df.describe()
# Out:
#          product_id     rating  ratings_count  initial_price    discount
# count  1.000000e+03  1000.0000    1000.000000     1000.00000  879.000000
# mean   1.713437e+07     3.6215      76.691000     2723.24100   53.503982
# std    3.813766e+06     1.3744     241.114263     2408.69736   18.029201
# min    5.868460e+05     0.0000       0.000000      249.00000    1.000000
# 25%    1.511501e+07     3.7000       7.000000     1399.00000   44.000000
# 50%    1.820890e+07     4.1000      17.000000     1999.00000   56.000000
# 75%    1.902737e+07     4.3000      58.000000     3299.00000   66.000000
# max    2.274707e+07     5.0000    4441.000000    22199.00000   88.000000

# %% [markdown]
# ## Step 5: Handling Missing Values
#
# In this step, I identify missing values in the dataset.

# %%
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
df.isna().mean()
# Out:
# product_id                0.000
# title                     0.000
# product_description       0.000
# rating                    0.000
# ratings_count             0.000
# initial_price             0.000
# discount                  0.121
# final_price               0.000
# currency                  0.000
# images                    0.000
# delivery_options          0.000
# product_details           0.000
# breadcrumbs               0.000
# product_specifications    0.000
# amount_of_stars           0.000
# what_customers_said       0.573
# seller_name               0.301
# sizes                     0.000
# videos                    0.781
# seller_information        0.301
# variations                0.562
# best_offer                0.000
# more_offers               0.000
# category                  0.000
# dtype: float64

# %% [markdown]
# ## Step 6: Fill Missing Values
#
# I fill missing values in numeric columns with mean and text columns with 'Unknown'.

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df.fillna("Unknown", inplace=True)
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %% [markdown]
# ## Step 7: Remove Duplicate Records
#
# In this step, I remove duplicate rows from the dataset.

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## Step 8: Basic Data Operations
#
# In this step, I perform filtering and column selection.

# %%
df[df['rating'] > 4]
# Out:
#      product_id              title  \
# 1       9136281     Tommy Hilfiger
# 2      17633752              Lavie
# 3       1376949             F Gear
# 4      13939916          MYTRIDENT
# 5      17198778                H&M
# ..          ...                ...
# 991     2466414       Daniel Klein
# 992    11791782              CASIO
# 994     8481603  French Connection
# 996    16896006              GUESS
# 998    19280114           Fastrack
#
#                                    product_description  rating  ratings_count  \
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# 5           Beige & Tan Solid Stoneware Soap Dispenser     4.5             42
# ...

# %%
df[['title', 'final_price', 'rating']]
# Out:
#               title   final_price  rating
# 0       Lino Perros   "₹3,995.00"     3.8
# 1    Tommy Hilfiger   "₹2,899.00"     4.5
# 2             Lavie   "₹2,999.00"     4.4
# 3            F Gear   "₹1,675.00"     4.4
# 4         MYTRIDENT   "₹2,899.00"     4.7
# ..              ...           ...     ...
# 995           KREDO  "₹11,890.00"     3.5
# 996           GUESS   "₹8,900.00"     5.0
# 997        GIORDANO   "₹7,950.00"     2.8
# 998        Fastrack   "₹2,636.00"     4.3
# 999         BOLDFIT     "₹699.00"     3.8
#
# [1000 rows x 3 columns]

# %%
df[['product_id', 'title', 'product_description']]
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description
# 0                       Women Navy Blue Solid Backpack
# 1                    Unisex Navy Blue Striped Backpack
# 2                       Aries Women Pink Mini Backpack
# 3           Unisex Navy & Grey Printed Burner Backpack
# 4                             Men Blue Solid Bath Robe
# ..                                                 ...
# 995  Men FORTE Silver Automatic Skeleton Analogue W...
# 996  Women White Patterned Dial & White Straps Anal...
# 997  Women Rose Gold-Toned Mirrored Analogue Watch ...
# ...

# %% [markdown]
# ## Step 9: Create Derived Column
#
# The dataset does not contain quantity,therefore I assume each product has quantity = 1.
# I create a new column 'total_amount' using final_price.

# %%
df['total_amount'] = df['final_price']

# %% [markdown]
# ## Step 10: Save Cleaned Dataset
#
# In this step, I save the cleaned dataset as a new CSV file.

# %%
df.to_csv("cleaned_dataset_final.csv", index=False)

# %% [markdown]
# ## Final Points
#
# In this task(Assignment), I successfully:
# 1)Loaded the dataset
# 2)Explored the data
# 3)Handled missing values
# 4)Removed duplicates
# 5)Performed basic operations (like filtering , column selection)
# 6)Created a derived column
# 7)Saved the cleaned dataset
#
# This demonstrates basic data cleaning and data preprocessing using pandas.
